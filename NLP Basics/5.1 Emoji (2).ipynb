# %%
text1 = 'Python is 👍'
text2 = "I was 🤓"
text3 = "😊 Good morning"
text4 = "Hello 🤓🔜🗣️"

# %% [markdown]
# ## Convert emoji into text

# %%
# !pip install emoji

# %%
import emoji

# %%
emoji.demojize(text1)
# Out:
# 'Python is :thumbs_up:'

# %%
emoji.demojize(text2)
# Out:
# 'I was :nerd_face:'

# %%
emoji.demojize(text3)
# Out:
# ':smiling_face_with_smiling_eyes: Good morning'

# %%
emoji.demojize(text4)
# Out:
# 'Hello :nerd_face::SOON_arrow::speaking_head:'

# %%
def demojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')

# %%
text1
# Out:
# 'Python is 👍'

# %%
demojify(text1)
# Out:
# 'Python is '

# %%
text2
# Out:
# 'I was 🤓'

# %%
demojify(text2)
# Out:
# 'I was '

# %%
text3
# Out:
# '😊 Good morning'

# %%
demojify(text3)
# Out:
# ' Good morning'

# %%
text4
# Out:
# 'Hello 🤓🔜🗣️'

# %%
demojify(text4)
# Out:
# 'Hello '

# %%
import pandas as pd

# %%
df = pd.read_csv("review (1).csv")
df.head()
# Out:
#    Unnamed: 0                                             review  sentiment
# 0           0  Not sure who was more lost - the flat characte...          0
# 1           1  Attempting artiness with black & white and cle...          0
# 2           2         Very little music or anything to speak of.          0
# 3           3  The best scene in the movie was when Gerardo i...          1
# 4           4  The rest of the movie lacks art, charm, meanin...          0

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# 1    500
# 0    499
# Name: count, dtype: int64

# %%
df["review"] = df["review"].apply(lambda x : emoji.demojize(x))

# %%
df["review"] = df["review"].apply(demojify)

# %%
df.head()
# Out:
#    Unnamed: 0                                             review  sentiment
# 0           0  Not sure who was more lost - the flat characte...          0
# 1           1  Attempting artiness with black & white and cle...          0
# 2           2         Very little music or anything to speak of.          0
# 3           3  The best scene in the movie was when Gerardo i...          1
# 4           4  The rest of the movie lacks art, charm, meanin...          0

# %%
dummy = pd.DataFrame({"text":['Python is 👍',"I was 🤓","😊 Smiling ace with Smiling Eyes","Hello 🤓🔜🗣️"], "sentiment":[1,0,0,1]})

# %%
dummy
# Out:
#                               text  sentiment
# 0                      Python is 👍          1
# 1                          I was 🤓          0
# 2  😊 Smiling ace with Smiling Eyes          0
# 3                       Hello 🤓🔜🗣️          1

# %%
dummy["text"] = dummy["text"].apply(lambda x : emoji.demojize(x))
dummy["text"] = dummy["text"].apply(demojify)

# %%
dummy
# Out:
#                                                 text  sentiment
# 0                              Python is :thumbs_up:          1
# 1                                  I was :nerd_face:          0
# 2  :smiling_face_with_smiling_eyes: Smiling ace w...          0
# 3       Hello :nerd_face::SOON_arrow::speaking_head:          1

# %%
df = pd.read_csv("news.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text label
# 0  Donald Trump just couldn t wish all Americans ...  fake
# 1  House Intelligence Committee Chairman Devin Nu...  fake
# 2  On Friday, it was revealed that former Milwauk...  fake
# 3  On Christmas day, Donald Trump announced that ...  fake
# 4  Pope Francis used his annual Christmas Day mes...  fake

# %%
df["news"] = df["title"] + " " + df["text"]

# %%
df.drop(["title","text"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   label                                               news
# 0  fake   Donald Trump Sends Out Embarrassing New Year’...
# 1  fake   Drunk Bragging Trump Staffer Started Russian ...
# 2  fake   Sheriff David Clarke Becomes An Internet Joke...
# 3  fake   Trump Is So Obsessed He Even Has Obama’s Name...
# 4  fake   Pope Francis Just Called Out Donald Trump Dur...

# %%
df.shape
# Out:
# (44898, 2)

# %%
df["label"].value_counts()
# Out:
# label
# fake    23481
# true    21417
# Name: count, dtype: int64
