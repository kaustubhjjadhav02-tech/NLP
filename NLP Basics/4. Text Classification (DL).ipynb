# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

# NN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,Embedding, Flatten

# preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence

# %%
df = pd.read_csv("spam (1).csv")
df.head()
# Out:
#    Category                                            Message
# 0  not spam  Go until jurong point, crazy.. Available only ...
# 1  not spam                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  not spam  U dun say so early hor... U c already then say...
# 4  not spam  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
# feature target split
X = df["Message"]
y = df["Category"]

# %%
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
# Keras tokenization

tok = Tokenizer()
tok.fit_on_texts(X_train)

# %%
vocabulary = tok.index_word
print(vocabulary)
# Out:
# {1: 'i', 2: 'to', 3: 'you', 4: 'a', 5: 'the', 6: 'u', 7: 'and', 8: 'is', 9: 'in', 10: 'me', 11: 'my', 12: 'for', 13: 'your', 14: 'it', 15: 'of', 16: 'call', 17: 'have', 18: 'that', 19: 'on', 20: '2', 21: 'are', 22: 'now', 23: 'so', 24: 'but', 25: 'not', 26: 'can', 27: 'if', 28: 'or', 29: 'ur', 30: 'at', 31: 'with', 32: 'get', 33: 'do', 34: 'will', 35: 'be', 36: "i'm", 37: 'no', 38: 'just', 39: 'this', 40: 'we', 41: '4', 42: 'when', 43: 'up', 44: 'ok', 45: 'go', 46: 'from', 47: 'gt', 48: 'lt', 49: 'how', 50: 'out', 51: 'free', 52: 'all', 53: 'what', 54: 'then', 55: 'got', 56: 'good', 57: 'like', 58: 'know', 59: 'come', 60: 'time', 61: 'its', 62: 'am', 63: 'was', 64: 'only', 65: 'day', 66: 'love', 67: 'want', 68: 'text', 69: 'he', 70: 'there', 71: 'send', 72: 'by', 73: 'going', 74: 'as', 75: 'ü', 76: 'about', 77: 'today', 78: "i'll", 79: 'txt', 80: 'one', 81: 'need', 82: 'stop', 83: 'back', 84: 'lor', 85: 'still', 86: 'see', 87: 'da', 88: 'home', 89: 'sorry', 90: 'later', 91: 'she', 92: 'reply', 93: 'dont', 94: 'r', 95: 'our', 96: 'n', 97: 'any', 98: 'tell', 99: 'hi', 100: 'her', 101: 'please', 102: 'they', 103: 'take', 104: 'k', 105: 'phone', 106: "don't", 107: 'mobile', 108: 'think', 109: 'has', 110: 'pls', 111: 'new', 112: 'been', 113: 'week', 114: 'him', 115: '1', 116: 'did', 117: 'dear', 118: 'some', 119: 'oh', 120: 'much', 121: 'who', 122: 'where', 123: 'here', 124: 'c', 125: 'claim', 126: 'night', 127: 'give', 128: 'an', 129: 'too', 130: 'msg', 131: 'well', 132: 'wat', 133: 'great', 134: 'had', 135: 'more', 136: 'hey', 137: 'd', 138: 'yes', 139: 'prize', 140: 'work', 141: 'say', 142: 'make', 143: "it's", 144: 'hope', 145: 'already', 146: 'ask', 147: 'www', 148: 'e', 149: 'doing', 150: 'way', 151: 'should', 152: 'cash', 153: 'very', 154: 'tomorrow', 155: 'really', 156: 'miss', 157: 'yeah', 158: 'why', 159: 'after', 160: 'right', 161: 'message', 162: 'im', 163: 'number', 164: 'lol', 165: 'also', 166: 'happy', 167: 'meet', 168: 'babe', 169: 'anything', 170: 'life', 171: 'thanks', 172: 'said', 173: 'morning', 174: '3', 175: 'sure', 176: 'would', 177: 'something', 178: 'last', 179: 'cos', 180: 'let', 181: 'them', 182: 'first', 183: 't', 184: 'care', 185: 'urgent', 186: 'again', 187: 'b', 188: 'pick', 189: 'before', 190: 'every', 191: 'won', 192: 'amp', 193: 'find', 194: 'told', 195: 'nokia', 196: 'gud', 197: 'even', 198: 'uk', 199: 'min', 200: 'sent', 201: 'us', 202: 'contact', 203: 'cant', 204: 'feel', 205: 's', 206: 'sms', 207: 'help', 208: 'tonight', 209: 'could', 210: 'next', 211: '150p', 212: '5', 213: 'his', 214: 'which', 215: 'win', 216: 'tone', 217: "that's", 218: 'ya', 219: 'x', 220: 'went', 221: 'keep', 222: 'someone', 223: "i've", 224: 'thing', 225: 'service', 226: 'customer', 227: 'friends', 228: 'other', 229: 'off', 230: 'over', 231: 'place', 232: 'many', 233: 'com', 234: 'co', 235: 'v', 236: 'dun', 237: 'gonna', 238: 'per', 239: 'always', 240: 'may', 241: 'late', 242: 'try', 243: 'hello', 244: 'yet', 245: 'coming', 246: 'money', 247: 'around', 248: "can't", 249: '16', 250: 'fine', 251: 'guaranteed', 252: 'holiday', 253: 'soon', 254: 'wait', 255: 'y', 256: 'leave', 257: '50', 258: 'special', 259: 'friend', 260: 'use', 261: 'talk', 262: 'buy', 263: 'were', 264: 'thk', 265: '7', 266: 'waiting', 267: 'chat', 268: "you're", 269: 'smile', 270: 'sleep', 271: 'heart', 272: 'same', 273: 'nice', 274: "didn't", 275: 'mins', 276: 'best', 277: 'wan', 278: '18', 279: 'down', 280: 'long', 281: 'meeting', 282: 'wish', 283: 'never', 284: 'haha', 285: 'being', 286: 'done', 287: 'ready', 288: 'ever', 289: 'cs', 290: 'name', 291: '6', 292: 'cool', 293: 'trying', 294: 'half', 295: 'lunch', 296: 'yup', 297: 'person', 298: 'line', 299: 'few', 300: 'stuff', 301: 'draw', 302: 'getting', 303: 'word', 304: 'things', 305: 'job', 306: 'sir', 307: 'class', 308: 'box', 309: 'wk', 310: 'bit', 311: 'ill', 312: 'start', 313: 'month', 314: 'lot', 315: 'end', 316: 'birthday', 317: 'year', 318: 'liao', 319: 'camera', 320: '1st', 321: 'real', 322: 'q ...

# %%
vocab_length = len(vocabulary)
vocab_length
# Out:
# 7382

# %%
# Sequence
train_sequence = tok.texts_to_sequences(X_train)
print(train_sequence)
# Out:
# [[53, 21, 13, 111, 500, 1013], [918, 5, 1123, 3493, 1295, 301, 74, 13, 3494], [1124, 58, 42, 1, 26, 1125, 72, 7, 188, 43, 36, 51, 1296, 97, 60, 159, 115, 52, 39, 850], [44, 103, 184, 1126, 2, 3, 129], [784, 57, 2, 98, 3, 11, 3495, 3496, 1297, 16, 10, 3497, 38, 2346, 199, 2, 82, 423, 16, 1127, 2347, 424], [1014, 1015, 13, 1816, 3498, 42, 1, 81, 14], [8, 14, 13, 1817, 2348, 18, 
 15, 29, 19, 17, 26, 29, 7, 9, 16, 36, 13, 12, 23, 57, 22, 9, 8, 14, 6, 14, 7, 11, 9, 26, 9, 11, 36, 19, 18, 30, 2, 8, 4, 43, 11, 15, 14, 30, 6, 30, 21, 4, 26, 7, 10, 8, 6, 8, 31, 16, 26, 27, 11, 5, 5, 5, 7, 6, 23, 7, 6, 12, 15, 12, 16, 9, 9, 27, 25, 17, 23, 5, 12, 16, 28, 15, 8, 9, 5, 7, 19, 6, 7, 28, 49, 5, 5, 7, 16, 8, 5, 9, 18, 26, 24, 6, 6, 23, 25, 5, 5, 10, 23, 3, 7, 4, 15, 26, 27, 13, 14, 16, 17, 25, 37, 25, 27, 10, 5, 14, 6, 5, 24, 30, 3, 6, 33, 27, 27, 23, 5, 18, 24, 34, 27, 22, 3, 32, 19, 8, 26, 23, 32, 8, 12, 29, 28, 28, 7, 19, 24, 10, 17, 23, 7, 27, 12, 19, 27, 6, 11, 38, 14, 7, 9, 15, 9, 7, 19, 22, 20, 19, 7, 13, 10, 14, 4, 13, 8, 31, 11, 17, 24, 6, 5, 9, 23, 11, 9, 7, 33, 12, 24, 30, 14, 16, 16, 28, 12, 21, 11, 8, 7, 29, 35, 10, 11, 9, 7, 22, 25, 6, 12, 28, 17, 6, 29, 6, 6, 7, 8, 12, 4, 28, 14, 28, 11, 28, 16, 15, 29, 7, 4, 11, 26, 24, 31, 7, 3, 19, 4, 25, 14, 7, 6, 19, 21, 8, 16, 7, 7, 11, 4, 14, 22, 31, 8, 8, 9, 25, 18, 14, 25, 6, 27, 8, 16, 16, 10, 3, 19, 10, 5, 27, 12, 25, 20, 5, 26, 13, 12, 1, 25, 4, 10, 21, 13, 16, 7, 11, 32, 9, 16, 24, 27, 7, 24, 12, 29, 6, 17, 7, 16, 4, 7, 17, 18, 16, 25, 10, 25, 9, 8, 5, 10, 16, 29, 15, 33, 21, 5, 13, 22, 11, 47, 15, 28, 28, 34, 29, 14, 26, 13, 11, 6, 28, 6, 32, 26, 5, 12, 23, 6, 15, 7, 30, 162, 33, 13, 12, 5, 30, 8, 22, 16, 6, 20, 4, 15, 26, 23, 28, 18, 29, 8, 6, 0, 6, 27, 2, 14, 33, 14, 28, 6, 7, 8, 32, 1, 15, 6, 8, 18, 11, 6, 12, 9, 3, 1, 35, 5, 29, 34, 24, 17, 6, 10, 29, 33, 29, 33, 26, 27, 11, 6, 24, 31, 5, 9, 28, 15, 12, 19, 6, 10, 23, 7, 17, 9, 6, 7, 20, 9, 11, 16, 33, 5, 21, 5, 18, 8, 12, 18, 30, 5, 22, 9, 17, 19, 15, ...

# %%
max(doc_length)
# Out:
# 189

# %%
# 95% quantile
# 95% document length is less than or equal to 33
np.quantile(doc_length, 0.95)
# Out:
# 33.0

# %%
# 99% quantile
# 99% document length is less than or equal to 51
np.quantile(doc_length, 0.99)
# Out:
# 51.00999999999976

# %%
max_length = 51

# %%
# Padding
train_matrix = sequence.pad_sequences(train_sequence,maxlen=max_length)
train_matrix
# Out:
# array([[   0,    0,    0, ...,  111,  500, 1013],
#        [   0,    0,    0, ...,   74,   13, 3494],
#        [   0,    0,    0, ...,   52,   39,  850],
#        ...,
#        [   0,    0,    0, ...,  121,  741, 7381],
#        [   0,    0,    0, ..., 1790, 7382, 1919],
#        [   0,    0,    0, ...,  267,   31,   10]])

# %%
# Testing data
test_sequence = tok.texts_to_sequences(X_test)
test_matrix = sequence.pad_sequences(test_sequence,maxlen=max_length)
test_matrix
# Out:
# array([[   0,    0,    0, ...,   72,    5,  719],
#        [   0,    0,    0, ...,  142,   10, 1592],
#        [   0,    0,    0, ..., 5282, 2962,   69],
#        ...,
#        [   0,    0,    0, ...,    0,  205, 1753],
#        [   0,    0,    0, ...,  171,   12,    5],
#        [   0,    0,    0, ...,   78,   16,   90]])

# %%
# model
model = Sequential()
model.add(Embedding(input_dim=vocab_length+1, # vocabulary length, +1 -> 0 tokens
                    input_length=max_length,  # max length of document -> 51
                    output_dim=100,           # hyperparameter -> vector length of each token
                    mask_zero=True))          # do not learn for 0 token
model.add(Flatten())
model.add(Dense(32,activation="relu"))
model.add(Dense(16,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
# Out:
# C:\Users\Kaustubh Jadhav\Downloads\Anaconda\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer="adam",loss="binary_crossentropy")
model.fit(train_matrix,y_train,epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# C:\Users\Kaustubh Jadhav\Downloads\Anaconda\Lib\site-packages\keras\src\layers\layer.py:965: UserWarning: Layer 'flatten' (of type Flatten) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.3240
# Epoch 2/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0888
# Epoch 3/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0089
# Epoch 4/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0040
# Epoch 5/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 2.8130e-04
# Epoch 6/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3150e-04
# Epoch 7/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.8068e-05
# Epoch 8/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.7056e-05
# Epoch 9/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.0695e-05
# Epoch 10/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.9941e-05
# Epoch 11/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.7103e-05
# Epoch 12/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2194e-05
# Epoch 13/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.2444e-05
# Epoch 14/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.6931e-05
# Epoch 15/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.5771e-05
# Epoch 16/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5290e-05
# Epoch 17/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.2156e-05
# Epoch 18/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.1214e-06
# Epoch 19/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 9.7646e-06
# Epoch 20/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 6.9355e-06

# %%
# prediction
y_pred = model.predict(test_matrix)
y_pred = np.where(y_pred >= 0.5, 1, 0)
print(classification_report(y_test,y_pred))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1442
#            1       0.99      0.92      0.95       230
#
#     accuracy                           0.99      1672
#    macro avg       0.99      0.96      0.97      1672
# weighted avg       0.99      0.99      0.99      1672

# %%
sms1 = "Hey how are you ? let's catchup"
sms2 = "FREE FREE, claim your prize worth $20000 and click on the following link http:fake.com"

# %%
def predict_sms(sms):
  data_seq = tok.texts_to_sequences([sms])
  data_matrix = sequence.pad_sequences(data_seq,maxlen=max_length)
  y_pred = model.predict(data_matrix)
  y_pred = np.where(y_pred >= 0.5, 1, 0)
  output = le.inverse_transform(y_pred[0])[0]
  return output

# %%
predict_sms(sms1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 'not spam'

# %%
predict_sms(sms2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 'spam'
